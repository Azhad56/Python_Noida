# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
data = np.load("faces.npy")

# %%
data
# Out:
# array([['Modi', '199', '198', ..., '207', '206', '207'],
#        ['Modi', '198', '198', ..., '205', '206', '206'],
#        ['Modi', '198', '200', ..., '205', '205', '206'],
#        ...,
#        ['Anonymous', '224', '224', ..., '213', '213', '213'],
#        ['Anonymous', '225', '225', ..., '215', '215', '215'],
#        ['Anonymous', '224', '224', ..., '215', '215', '215']], dtype='<U9')

# %%
X = data[:,1:]
y = data[:,0]

# %%
single_face = np.array(X[20].reshape(100,100).astype(np.int64))

# %%
plt.imshow(single_face)

# %%
y
# Out:
# array(['Modi', 'Modi', 'Modi', 'Modi', 'Modi', 'Modi', 'Modi', 'Modi',
#        'Modi', 'Modi', 'Obama', 'Obama', 'Obama', 'Obama', 'Obama',
#        'Obama', 'Obama', 'Obama', 'Obama', 'Obama', 'Anonymous',
#        'Anonymous', 'Anonymous', 'Anonymous', 'Anonymous', 'Anonymous',
#        'Anonymous', 'Anonymous', 'Anonymous', 'Anonymous'], dtype='<U9')
