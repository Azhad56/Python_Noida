# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.goodreads.com/quotes/tag/{}?page={}"

# %%
def scrap(url):
    data = requests.get(url)

    soup = BeautifulSoup(data.text)

    quote_divs = soup.find_all("div", attrs={"class":"quote"})

    content = []

    for quote_div in quote_divs:

        quoteText_div = quote_div.find("div", attrs={"class":"quoteText"})
        quoteText = quoteText_div.text
        author = quoteText_div.find("span").text.strip()
        quote = quoteText.strip().split("\n")[0][1:-1]
        left = quote_div.find("div", attrs={"class":"left"})
        tags = ", ".join([a.text for a in left.find_all("a")])
        content.append([author, quote, tags])
    
    return content

# %%
emotion = input("Enter the emotion : ")
pages = int(input("Enter number of pages : "))
# Out:
# Enter the emotion :  life
# Enter number of pages :  3

# %%
collected = []
for num in range(1, pages + 1):
    collected.extend(scrap(url.format(emotion, num)))
    print("processes", num)
# Out:
# processes 1
# processes 2
# processes 3

# %%
len(collected)
# Out:
# 90

# %%
import pandas as pd

# %%
pd.DataFrame(collected, columns=["author", "quote", "tags"])
# Out:
#                       author  \
# 0             Marilyn Monroe
# 1          William W. Purkey
# 2                   Mae West
# 3               Robert Frost
# 4                Oscar Wilde
# 5        Narcotics Anonymous
# 6                Andre Gide,
# 7              J.K. Rowling,
# 8            Albert Einstein
# 9                 Mark Twain
# 10            Allen Saunders
# 11            douglas adams,
# 12            Marilyn Monroe
# 13             Pablo Picasso
# 14                 Dr. Seuss
# 15                Dr. Seuss,
# 16               Woody Allen
# 17       George Bernard Shaw
# 18             Markus Zusak,
# 19           Albert Einstein
# 20               John Green,
# 21           Bill Watterson,
# 22                Bob Marley
# 23          Stephen Chbosky,
# 24               John Green,
# 25             J.K. Rowling,
# 26            Jess C. Scott,
# 27  Bessie Anderson Stanley,
# 28       Ralph Waldo Emerson
# 29             Jimi Hendrix,
# ..                       ...
# 60             J.K. Rowling,
# 61                May Sarton
# 62               Oscar Wilde
# 63             Rick Riordan,
# 64          Cassandra Clare,
# 65               John Lennon
# 66       George Bernard Shaw
# 67         Søren Kierkegaard
# 68  John Greenleaf Whittier,
# 69                Chad Sugg,
# 70                 Ayn Rand,
# 71              Stephen King
# 72      Walt Disney Company,
# 73         Abigail Van Buren
# 74            Audrey Hepburn
# 75       Ralph Waldo Emerson
# 76           Lemony Snicket,
# 77                Alan Moore
# 78              maya angelou
# 79               Woody Allen
# 80          Arthur C. Clarke
# 81              Albert Camus
# 82             George Carlin
# 83         Douglas Coupland,
# 84          Terry Pratchett,
# 85              Jim Morrison
# 86          Khaled Hosseini,
# 87          William Goldman,
# 88           Roy T. Bennett,
# 89            Dale Carnegie,
#
#                                                 quote  \
# 0   I'm selfish, impatient and a little insecure. ...
# 1   You've gotta dance like there's nobody watchin...
# 2   You only live once, but if you do it right, on...
# 3   In three words I can sum up everything I've le...
# 4   To live is the rarest thing in the world. Most...
# 5   Insanity is doing the same thing, over and ove...
# 6   It is better to be hated for what you are than...
# 7   It does not do to dwell on dreams and forget t...
# 8   There are only two ways to live your life. One...
# 9   Good friends, good books, and a sleepy conscie...
# 10  Life is what happens to us while we are making...
# 11  I may not have gone where I intended to go, bu...
# 12  This life is what you make it. No matter what,...
# 13                Everything you can imagine is real.
# 14  Sometimes the questions are complicated and th...
# 15  Today you are You, that is truer than true. Th...
# 16  I'm not afraid of death; I just don't want to ...
# 17  Life isn't about finding yourself. Life is abo...
# 18  Sometimes people are beautiful.Not in looks.No...
# 19  Life is like riding a bicycle. To keep your ba...
# 20  Some infinities are bigger than other infinities.
# 21                 Reality continues to ruin my life.
# 22  Who are you to judge the life I live?I know I'...
