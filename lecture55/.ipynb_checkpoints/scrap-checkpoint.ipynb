# %%
import requests
url = "https://www.goodreads.com/quotes"
data = requests.get(url)

# %%
# data.text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
# soup.find_all("a")

# %% [markdown]
# <h1>Hi</h1>
# <p> Ham jaha bakchodi waha </p>
# <h1>bye</h1>
# <h1>Fi fi</h1>
#
# <a href="https://google.com"> Link to Google </a>

# %%
quote_divs = soup.find_all("div", attrs={"class":"quote"})

quote_div = quote_divs[0]

quoteText_div = quote_div.find("div", attrs={"class":"quoteText"})

quoteText_div

quoteText = quoteText_div.text

quoteText

author = quoteText_div.find("span").text.strip()

quote = quoteText.strip().split("\n")[0]

# %%
left = quote_div.find("div", attrs={"class":"left"})

[a.text for a in left.find_all("a")]

# %%
quote_divs = soup.find_all("div", attrs={"class":"quote"})

content = []

for quote_div in quote_divs:

    quoteText_div = quote_div.find("div", attrs={"class":"quoteText"})
    quoteText = quoteText_div.text
    author = quoteText_div.find("span").text.strip()
    quote = quoteText.strip().split("\n")[0][1:-1]
    content.append([author, quote])

# %%
# content

# %%
import pandas as pd

# %%
pd.DataFrame(content, columns=["author", "quote"])
# Out:
#                      author                                              quote
# 0            Marilyn Monroe  I'm selfish, impatient and a little insecure. ...
# 1               Oscar Wilde       Be yourself; everyone else is already taken.
# 2           Albert Einstein  Two things are infinite: the universe and huma...
# 3               Frank Zappa                     So many books, so little time.
# 4         Bernard M. Baruch  Be who you are and say what you feel, because ...
# 5     Marcus Tullius Cicero  A room without books is like a body without a ...
# 6         William W. Purkey  You've gotta dance like there's nobody watchin...
# 7                 Dr. Seuss  You know you're in love when you can't fall as...
# 8                  Mae West  You only live once, but if you do it right, on...
# 9            Mahatma Gandhi   Be the change that you wish to see in the world.
# 10             Robert Frost  In three words I can sum up everything I've le...
# 11            J.K. Rowling,  If you want to know what a man's like, take a ...
# 12             Albert Camus  Don’t walk in front of me… I may not followDon...
# 13       Eleanor Roosevelt,  No one can make you feel inferior without your...
# 14              C.S. Lewis,  Friendship ... is born at the moment when one ...
# 15               Mark Twain  If you tell the truth, you don't have to remem...
# 16             Maya Angelou  I've learned that people will forget what you ...
# 17           Elbert Hubbard  A friend is someone who knows all about you an...
# 18              Oscar Wilde  Always forgive your enemies; nothing annoys th...
# 19              Oscar Wilde  To live is the rarest thing in the world. Most...
# 20           Mahatma Gandhi  Live as if you were to die tomorrow. Learn as ...
# 21  Martin Luther King Jr.,  Darkness cannot drive out darkness: only light...
# 22             Oscar Wilde,  I am so clever that sometimes I don't understa...
# 23     Friedrich Nietzsche,            Without music, life would be a mistake.
# 24         Stephen Chbosky,            We accept the love we think we deserve.
# 25      Ralph Waldo Emerson  To be yourself in a world that is constantly t...
# 26             Rob Siltanen  Here's to the crazy ones. The misfits. The reb...
# 27      Narcotics Anonymous  Insanity is doing the same thing, over and ove...
# 28           Marilyn Monroe  I believe that everything happens for a reason...
# 29    H. Jackson Brown Jr.,  Twenty years from now you will be more disappo...
