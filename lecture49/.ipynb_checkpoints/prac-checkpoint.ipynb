# %%
from gensim.models import Word2Vec

# %%
! wget "https://cb.lk/speech"
# Out:
# --2020-04-25 14:44:25--  https://cb.lk/speech
# Resolving cb.lk (cb.lk)... 159.89.170.74
# Connecting to cb.lk (cb.lk)|159.89.170.74|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/coding-blocks-archives/ML-Noida-2019-June-Two/master/datasets/speeches/speech.txt [following]
# --2020-04-25 14:44:26--  https://raw.githubusercontent.com/coding-blocks-archives/ML-Noida-2019-June-Two/master/datasets/speeches/speech.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.20.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.20.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1733053 (1.7M) [text/plain]
# Saving to: ‘speech’
#
# speech              100%[===================>]   1.65M   400KB/s    in 4.1s
#
# 2020-04-25 14:44:32 (412 KB/s) - ‘speech’ saved [1733053/1733053]

# %%
with open("speech") as f:
    text = f.read()

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
sents = sent_tokenize(text)

# %%
sents_words = [word_tokenize(sent.lower()) for sent in sents]

# %%
len(sents)
# Out:
# 17939

# %%
model = Word2Vec(sents_words)

# %%
model.wv.vocab
# Out:
# {'26': <gensim.models.keyedvectors.Vocab at 0x7fbe2f78ed50>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7fbe2f78ef50>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x7fbe2f78e2d0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7fbe37ef3f10>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7fbe37ef3f50>,
#  'niti': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d4d0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d290>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d950>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7fbe37ef3c50>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fbe37ef3ed0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4dad0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4db90>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4da90>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4ded0>,
#  'depend': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4de10>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d410>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4dd90>,
#  'quantity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4db10>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4dd50>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4df10>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d810>,
#  'labour': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d990>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d790>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4dc90>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d610>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4ddd0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d8d0>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4da10>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d450>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4de90>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d250>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d690>,
#  'institutions': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4de50>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d550>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d9d0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4dd10>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4df90>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d390>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d3d0>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d2d0>,
#  'namely': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc4d590>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17210>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17c90>,
#  'transforming': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17c10>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc174d0>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17950>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17910>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17a50>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17a10>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17990>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc176d0>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17cd0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17c50>,
#  'transformation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17850>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17790>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17890>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17610>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17590>,
#  'mainstream': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17550>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17b50>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17b90>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc178d0>,
#  'policies': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc172d0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17690>,
#  'collaboration': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc17050>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc173d0>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11a90>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11850>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11790>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11510>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc112d0>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11890>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11590>,
#  'practitioners': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11b50>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11ed0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11190>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11b90>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11a10>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11a50>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11290>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11b10>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11950>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc115d0>,
#  'administrative': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11210>,
#  'tradition': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc119d0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc11390>,
#  'indigenous': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc136d0>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13090>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13290>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13410>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13190>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13790>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc132d0>,
#  'ways': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13910>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13890>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13b90>,
#  'democracy': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13510>,
#  'federalism': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13fd0>,
#  'unity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13ed0>,
#  'integrity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13350>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13550>,
#  'glorious': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13810>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc13710>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e650>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e110>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e350>,
#  'achievements': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e3d0>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ed10>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ead0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ee90>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e4d0>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e750>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ea10>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ec50>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ec10>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0eed0>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0ed90>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e050>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e290>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e510>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e390>,
#  'experiences': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e1d0>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc0e410>,
#  'strengths': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09d10>,
#  'thirty': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09e50>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09190>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09050>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09150>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc098d0>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09590>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09950>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc093d0>,
#  'solutions': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09990>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09390>,
#  'inter': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09810>,
#  'dependent': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc097d0>,
#  'connected': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09a90>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09490>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09450>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09750>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc096d0>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09110>,
#  'isolation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc090d0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc09410>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00310>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00210>,
#  'standards': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00250>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00690>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc009d0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00650>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00710>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00490>,
#  'younger': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00350>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00a50>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00810>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc002d0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00550>,
#  'differently': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00fd0>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc007d0>,
#  'rooted': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00b50>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00f50>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00e90>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00e50>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00cd0>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00dd0>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00450>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00c90>,
#  'elders': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00990>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00ed0>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00ad0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00a90>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00190>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00910>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00950>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc008d0>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00b90>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00c10>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00750>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00110>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc005d0>,
#  'challenge': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00590>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00850>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc006d0>,
#  'expectations': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc001d0>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00410>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc00150>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03710>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03090>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03350>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03450>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03150>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03b10>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03550>,
#  'rapid': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03dd0>,
#  'evolution': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03e50>,
#  '•': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03ad0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03f90>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03e10>,
#  'governance': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03a50>,
#  'mindset': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03c90>,
#  'transformative': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03cd0>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03f10>,
#  'eliminate': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03d90>,
#  'unnecessary': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03810>,
#  'procedures': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03d10>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03690>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc036d0>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03650>,
#  'adopt': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03790>,
#  'march': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc035d0>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc030d0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03250>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc031d0>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc03510>,
#  'fundamental': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9dd0>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9e50>,
#  'mindsets': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9310>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf90d0>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9610>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9c50>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf95d0>,
#  'democratic': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9950>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9390>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9a50>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9150>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9f10>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9f90>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9d10>,
#  'ourselves': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9b90>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9bd0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9b50>,
#  'absorb': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9c90>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9ad0>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9910>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9550>,
#  'articles': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9890>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf96d0>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9250>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9210>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf94d0>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9350>,
#  'collectively': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9190>,
#  'confined': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf9290>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf60d0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6150>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6390>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6410>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf62d0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6350>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6e90>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6ed0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6d50>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6d90>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6fd0>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6c90>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6b90>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6690>,
#  'collective': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6750>,
#  'convert': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6510>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6310>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6050>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6550>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf63d0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf61d0>,
#  'perspectives': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6290>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6110>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6650>,
#  'concerted': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf6210>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5cd0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5290>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5310>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5050>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5110>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5650>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf57d0>,
#  'personally': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5750>,
#  'participated': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5b10>,
#  'sessions': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5e50>,
#  'bankers': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5e10>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5c10>,
#  'officers': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5350>,
#  'secretaries': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5950>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5a50>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5410>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5d50>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5dd0>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5d10>,
#  'tap': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5f90>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5fd0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5b50>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf59d0>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5c50>,
#  'indians': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5590>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf55d0>,
#  'elsewhere': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5810>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5690>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5210>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf5450>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf52d0>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf51d0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0590>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0390>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0550>,
#  'directions': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0850>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf07d0>,
#  'lecture': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0610>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0cd0>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0d50>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0a90>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0a50>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0a10>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf09d0>,
#  'wisdom': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0210>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf00d0>,
#  'eminent': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0ed0>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0f90>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0d90>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0950>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0c10>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0c50>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0bd0>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0e90>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0d10>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9990>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9710>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9d50>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd95d0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9450>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9f50>,
#  'frank': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9310>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9d10>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9790>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbd9490>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x7fbe37b8e390>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7fbe37b8e490>,
#  'names': <gensim.models.keyedvectors.Vocab at 0x7fbe37b8e110>,
#  'conduct': <gensim.models.keyedvectors.Vocab at 0x7fbe1fd4a510>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7fbe1fd71ed0>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20bcd0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20bd50>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x7fbe1fd51d10>,
#  'emerge': <gensim.models.keyedvectors.Vocab at 0x7fbe1fd51110>,
#  'session': <gensim.models.keyedvectors.Vocab at 0x7fbe1fd51690>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0b50>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf03d0>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0810>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf06d0>,
#  'wherever': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0f50>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0450>,
#  'ministers': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0690>,
#  'participate': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0410>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbf0250>,
#  'transformed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc14f90>,
#  'singapore': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdd110>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed210>,
#  'shri': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed590>,
#  'shanmugaratnam': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed1d0>,
#  'deputy': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed4d0>,
#  'prime': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed550>,
#  'minister': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedc10>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed410>,
#  'scholar': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed450>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed250>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed690>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed6d0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed5d0>,
#  'finance': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedc50>,
#  'chairman': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedb10>,
#  'monetary': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedb50>,
#  'authority': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedad0>,
#  'manpower': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbedbd0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed510>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed150>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed3d0>,
#  'fifty': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed350>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed610>,
#  'sri': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed2d0>,
#  'lankan': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed750>,
#  'tamil': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbed490>,
#  'earned': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3710>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe33d0>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3150>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3390>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3990>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3bd0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3790>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3c50>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3510>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3c90>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3810>,
#  'honoured': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3b10>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3b50>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3ad0>,
#  'outstanding': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3c10>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe37d0>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3690>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe36d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3650>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe38d0>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3750>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3610>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbe3a50>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda190>,
#  'warming': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda990>,
#  'caps': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda8d0>,
#  'navigation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdaa50>,
#  'routes': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdab50>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda210>,
#  'relevance': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda4d0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda790>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda450>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda910>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda2d0>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda5d0>,
#  'possibility': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda110>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda750>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdab90>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda890>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda850>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda6d0>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdaa10>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdae50>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda1d0>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda290>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbdad90>,
#  'pleasure': <gensim.models.keyedvectors.Vocab at 0x7fbe2fbda590>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55090>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55350>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55bd0>,
#  'delimiter': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55290>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc553d0>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55c10>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55650>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55590>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55550>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55310>,
#  'excellency': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55790>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55110>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55390>,
#  'zuma': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55810>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55690>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55710>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55490>,
#  'generous': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55850>,
#  'hospitality': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55d50>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55750>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55e50>,
#  'delegation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc552d0>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc557d0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55210>,
#  'deeply': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55410>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55f50>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55ed0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55f10>,
#  'homage': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc55510>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fd90>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fd50>,
#  'souls': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fe50>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fd10>,
#  'mahatma': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fe10>,
#  'gandhi': <gensim.models.keyedvectors.Vocab at 0x7fbe2fb5fe90>,
#  'mandela': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53cd0>,
#  'centuries': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53250>,
#  'nurtured': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53850>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53550>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53750>,
#  'stood': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc535d0>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53690>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53b50>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53410>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53c90>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53e10>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53d90>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53ad0>,
#  'suffering': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc532d0>,
#  'struggles': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc530d0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc534d0>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53450>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc538d0>,
#  'partnership': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53190>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53c10>,
#  'discussions': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53210>,
#  'reviewed': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53d50>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53c50>,
#  'spectrum': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc53ed0>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7fbe38091650>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x7fbe3808b390>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7fbe3808bf10>,
#  'concrete': <gensim.models.keyedvectors.Vocab at 0x7fbe3808b2d0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fbe3808bdd0>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x7fbe3808b890>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc500d0>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50050>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50110>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50090>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50610>,
#  'companies': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50510>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50650>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50f50>,
#  'interests': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50b10>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50390>,
#  'investments': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc503d0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50d90>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50e10>,
#  'investment': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc501d0>,
#  'ties': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50210>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50410>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50450>,
#  'minerals': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50350>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50b90>,
#  'chemicals': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc508d0>,
#  'pharmaceuticals': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50150>,
#  'manufacturing': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50750>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50bd0>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50c10>,
#  'convinced': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50a90>,
#  'industry': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50a50>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50950>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc509d0>,
#  'gains': <gensim.models.keyedvectors.Vocab at 0x7fbe2fc50250>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e1d0>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e090>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e110>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e150>,
#  'robust': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e210>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e250>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e290>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e310>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e350>,
#  'synergies': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e390>,
#  'engagement': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e3d0>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e410>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e490>,
#  'economies': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e550>,
#  'demands': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e5d0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e610>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e650>,
#  'improving': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e710>,
#  'capacities': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e750>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e790>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e7d0>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e810>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e910>,
#  'complement': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49e950>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ead0>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ea50>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ea90>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49eb10>,
#  'expertise': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49eb50>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49eb90>,
#  'links': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ec90>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ecd0>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ed10>,
#  'defence': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ed90>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49edd0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ee10>,
#  'sectors': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ef10>,
#  'witnessing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ef50>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49ef90>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7fbe2f49efd0>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e3d0>,
#  'opportunities': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e510>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e550>,
#  'jointly': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e5d0>,
#  'manufacture': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e610>,
#  'platforms': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e650>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e690>,
#  'respond': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e710>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e790>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e7d0>,
#  'closely': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e810>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e850>,
#  'emerging': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e910>,
#  'challenges': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e950>,
#  'thanked': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e990>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20e9d0>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ea10>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20eb50>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20eb90>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ebd0>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ec10>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ec90>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ecd0>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ed10>,
#  'renewable': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ed50>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ed90>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ee10>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ee50>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20eed0>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ef50>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20ef90>,
#  'alliance': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20efd0>,
#  'cop': <gensim.models.keyedvectors.Vocab at 0x7fbe2d20eb10>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0050>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0090>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a00d0>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0110>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0150>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0190>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a01d0>,
#  'promoting': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0250>,
#  'thankful': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a02d0>,
#  '120': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0310>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0350>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0390>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a03d0>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0410>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0450>,
#  'attacks': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0490>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0610>,
#  'foundations': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a06d0>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0750>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0790>,
#  'vigilant': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0510>,
#  'cooperate': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a08d0>,
#  'actively': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0910>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0990>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a09d0>,
#  'waters': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0a10>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0a50>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0ad0>,
#  'frontiers': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0b10>,
#  'rim': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0b50>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0b90>,
#  'emerged': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0c10>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0cd0>,
#  'maritime': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0d10>,
#  'neighbours': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0d50>,
#  'chairmanship': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0dd0>,
#  'organization': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0e10>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0e50>,
#  'priorities': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0e90>,
#  'agenda': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0ed0>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0f50>,
#  'brics': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0f90>,
#  'welcoming': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0fd0>,
#  'summit': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a0890>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1050>,
#  'october': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a10d0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1110>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1150>,
#  'ports': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1190>,
#  'gujarat': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1210>,
#  'shores': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1310>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1350>,
#  'vast': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1450>,
#  'oceans': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1490>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1510>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1610>,
#  'determination': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a16d0>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1710>,
#  'excellence': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1750>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1590>,
#  'exceptional': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1850>,
#  'mozambique': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1890>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1910>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1950>,
#  'nyusi': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1990>,
#  'ladies': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a19d0>,
#  'gentlemen': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1a10>,
#  'touched': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1a50>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1b10>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1b90>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1b50>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1c10>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1c50>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1c90>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1d50>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1dd0>,
#  'testimony': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1e10>,
#  'traditions': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1e90>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1ed0>,
#  'commerce': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1f10>,
#  'suffered': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1fd0>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a1ad0>,
#  'colonial': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2090>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2110>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2190>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2210>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a22d0>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2390>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2350>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2410>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2450>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a24d0>,
#  'applaud': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a25d0>,
#  'fastest': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2610>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2650>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2690>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a26d0>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2710>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2790>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a27d0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2810>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2850>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a28d0>,
#  'committed': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2910>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2950>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2990>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a29d0>,
#  'anniversary': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2a10>,
#  'independence': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2a50>,
#  'establishment': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2a90>,
#  'diplomatic': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2ad0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2b10>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2b50>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2bd0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2c50>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2d10>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2d50>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2d90>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2dd0>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2e10>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2e50>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2e90>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2ed0>,
#  'india-africa': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2f10>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2f90>,
#  'aware': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2fd0>,
#  '34': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a2290>,
#  'gap': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3050>,
#  'confident': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a30d0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3110>,
#  'excellencies': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3150>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3190>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a31d0>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3290>,
#  'happiness': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a32d0>,
#  'well-being': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3350>,
#  'lasting': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3410>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3450>,
#  'prosperity': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3550>,
#  'bonds': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3590>,
#  'friendship': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a35d0>,
# ...
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3e90>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3f10>,
#  'freshness': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3f50>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3fd0>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a3dd0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a70d0>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7050>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7090>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7150>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7190>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7210>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7250>,
#  'itself': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7290>,
#  'enthusiasm': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7310>,
#  'extend': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7350>,
#  'farmer': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a73d0>,
#  'farmers': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7410>,
#  'achieving': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7450>,
#  'fronts': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a75d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7110>,
#  'heights': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7550>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7590>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7610>,
#  'nurture': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7650>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7690>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a76d0>,
#  'keen': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7710>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7750>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a77d0>,
#  'youngsters': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7810>,
#  'zeal': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7850>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7890>,
#  'generations': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7910>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7510>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7990>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a79d0>,
#  'pune': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7a10>,
#  'occasion': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7a50>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7a90>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7ad0>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7b10>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7b50>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7bd0>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7c50>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7c90>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7d10>,
#  'satellite': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7d90>,
#  'launched': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7950>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7f10>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7e90>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7ed0>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7f50>,
#  'interact': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a7f90>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4050>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4090>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a40d0>,
#  'contributions': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4110>,
#  'academic': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4150>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4190>,
#  'courage': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a41d0>,
#  'ambition': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4250>,
#  'dreams': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4290>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a42d0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4310>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4410>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4350>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a43d0>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4490>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a44d0>,
#  'chennai': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4510>,
#  'nadu': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4550>,
#  'hearing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4590>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a45d0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4610>,
#  'wishes': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4650>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a46d0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4710>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4790>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4810>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4390>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4910>,
#  'satellites': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4990>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a49d0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4a10>,
#  'valuable': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4a50>,
#  'deserve': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4a90>,
#  'congratulations': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4ad0>,
#  'congratulate': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4b10>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4b50>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4b90>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4bd0>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a48d0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4c50>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4c90>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4cd0>,
#  'joy': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4d10>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4d50>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4e50>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4e90>,
#  'soil': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4f90>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4fd0>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a4ed0>,
#  'owing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9050>,
#  'guarantee': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9090>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a90d0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9150>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9190>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a91d0>,
#  'launching': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9210>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9250>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9290>,
#  'educate': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9310>,
#  'beti': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9350>,
#  'bachao': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9390>,
#  'padhao': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9410>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9450>,
#  'heartfelt': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a94d0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9510>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9550>,
#  'incidents': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a95d0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9610>,
#  'slogan': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9650>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a92d0>,
#  '10th': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9690>,
#  '12th': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9710>,
#  'classes': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a97d0>,
#  'daughters': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9810>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9850>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9890>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a98d0>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9910>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9990>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a96d0>,
#  'fighter': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9a10>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9ad0>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9b10>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9b50>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9b90>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9c50>,
#  'officer': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9c90>,
#  'accomplished': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9cd0>,
#  'madhya': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9d50>,
#  'pradesh': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9d90>,
#  'bihar': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9dd0>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a99d0>,
#  'hail': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9e50>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9e90>,
#  'cities': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9ed0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9f50>,
#  'respective': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9f90>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4a9e10>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa090>,
#  'towns': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa0d0>,
#  'heartiest': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa110>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa150>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa190>,
#  '21st': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa290>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa350>,
#  'organised': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa490>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa3d0>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa450>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa4d0>,
#  'yoga': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa510>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa610>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa690>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa6d0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa710>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa750>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa7d0>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa890>,
#  'bond': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa8d0>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa950>,
#  'celebrated': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa990>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa9d0>,
#  'lakh': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaa10>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaa50>,
#  'atmosphere': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaa90>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaad0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aab10>,
#  'chandigarh': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aab50>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aab90>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aabd0>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aac10>,
#  'alike': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aac50>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aac90>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aacd0>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aad10>,
#  'organisation': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aad50>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aadd0>,
#  'quarters': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aa410>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aae90>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaed0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aaf50>,
#  'organized': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aafd0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aae50>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab090>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab110>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab150>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab190>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab1d0>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab210>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab2d0>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab390>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab3d0>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab450>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab290>,
#  'carried': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab4d0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab510>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab550>,
#  'pleasant': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab590>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab5d0>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab610>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab650>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab690>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab750>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab810>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab8d0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab910>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab950>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab9d0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aba10>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aba50>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4aba90>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abad0>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ab490>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abb90>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abbd0>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abc10>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abc90>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abcd0>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abd10>,
#  'ji': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abdd0>,
#  'suggestion': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abb10>,
#  'observe': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abe50>,
#  'carefully': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abe90>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abf50>,
#  't.v': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abfd0>,
#  'channels': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4abe10>,
#  'contribution': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac090>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac0d0>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac110>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac150>,
#  'dedicated': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac190>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac250>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fbe2f4ac290>,
#  ...}
