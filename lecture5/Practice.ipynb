# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
navaz_pil = Image.open('663574278-nawauddin_8.jpg')
chashma_pil = Image.open('chashma2.png')
cigarette = Image.open('ciggarette.png')

# %%
resize_chashma_pil = chashma_pil.resize((120,120),Image.ANTIALIAS)
cigarette = cigarette.resize((120,120),Image.ANTIALIAS)

# %%
navaz_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=425x320 at 0x7F75FE201710>

# %%
resize_chashma_pil
# Out:
# <PIL.Image.Image image mode=RGBA size=120x120 at 0x7F75FDD941D0>

# %%
cigarette
# Out:
# <PIL.Image.Image image mode=RGBA size=120x120 at 0x7F75FDDACF10>

# %%
navaz_np = np.array(navaz_pil)
chashma_np = np.array(resize_chashma_pil)
cigarette_np = np.array(cigarette)

# %%
navaz_np.shape
# Out:
# (320, 425, 3)

# %%
chashma_np.shape
# Out:
# (120, 120, 4)

# %%
cigarette_np.shape
# Out:
# (120, 120, 4)

# %%
plt.imshow(navaz_np)

# %%
plt.imshow(chashma_np)

# %%
plt.imshow(cigarette_np)

# %%
#half_chashma_np = chashma_np[::2,::2]

# %%
chashma_np.shape
# Out:
# (120, 120, 4)

# %%
plt.imshow(chashma_np)

# %%
chashma_np.shape
# Out:
# (120, 120, 4)

# %%
w_chashma = chashma_np.shape[1]
h_chashma = chashma_np.shape[0]

x_chashma=170
y_chashma=-30

w_cigarette = cigarette_np.shape[1]
h_cigarette = cigarette_np.shape[0]

x_cigarette = 90
y_cigarette = 55

# %%
cut = navaz_np[y_chashma:y_chashma+h_chashma,x_chashma:x_chashma+w_chashma]
cut = navaz_np[y_cigarette:y_cigarette+h_cigarette,x_cigarette:x_cigarette+w_cigarette]

# %%
for row in range(chashma_np.shape[0]):
    for col in range(chashma_np.shape[1]):
        if chashma_np[row,col,3] >100:
            cut[row,col] = chashma_np[row,col,:3]
            

for row in range(cigarette_np.shape[0]):
    for col in range(cigarette_np.shape[1]):
        if cigarette_np[row,col,3] >100:
            cut[row,col] = cigarette_np[row,col,:3]

# %%
plt.imshow(navaz_np)

# %%
cigarette
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150 at 0x7F3883351690>
