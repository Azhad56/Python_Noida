# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
pandas = Image.open('/home/azhad56/Desktop/Data-Noida-2020-Train-master/lecture_01/panda.jpg')

# %%
cb = Image.open('cb_tshirt_logo.png')

# %%
pandas_np = np.array(pandas)

# %%
cb_np = np.array(cb)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
w = cb_np.shape[1]
h = cb_np.shape[0]

x = 100
y= 100

# %%
cut = pandas_np[y:y+h,x:x+w]

# %%
cut.shape
# Out:
# (189, 454, 3)

# %%
plt.imshow(cut)

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if cb_np[row,col,3] >100:
            cut[row,col] = cb_np[row,col,:3]

# %%
plt.imshow(pandas_np)

# %%
file = open('overlay.jpg','wb')

# %%
overlay_arr = Image.fromarray(pandas_np)

# %%
overlay_arr.save(file)
