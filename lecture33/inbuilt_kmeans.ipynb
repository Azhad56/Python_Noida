# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(centers=6, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1],c = _)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(6, n_init=1)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
model.labels_
# Out:
# array([0, 0, 3, 5, 5, 2, 4, 4, 4, 3, 3, 2, 5, 4, 4, 1, 0, 0, 2, 1, 1, 2,
#        3, 5, 1, 1, 5, 1, 0, 4, 2, 5, 1, 0, 1, 1, 3, 3, 3, 4, 2, 2, 4, 4,
#        1, 3, 4, 5, 1, 0, 0, 2, 2, 2, 4, 1, 1, 5, 3, 3, 2, 3, 0, 2, 5, 0,
#        0, 0, 5, 0, 1, 2, 5, 2, 5, 1, 4, 5, 1, 5, 0, 2, 5, 4, 5, 3, 1, 3,
#        3, 3, 5, 4, 2, 2, 5, 3, 5, 3, 4, 4], dtype=int32)

# %%
plt.scatter(X[:, 0], X[:, 1], c=model.labels_)

# %%
plt.scatter(X[:, 0], X[:, 1], c=model.labels_)
for center in model.cluster_centers_:
    plt.scatter(center[0], center[1], s=120)
