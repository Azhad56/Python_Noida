# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
with open("index.html") as f:
    text = f.read()

# %%
print(text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Text Input</h2>
#
# <form>
#   First name:<br>
#   <input type="text" name="firstname">
#   <br>
#   Last name:<br>
#   <input type="text" name="lastname">
# </form>
#
# <p>Note that the form itself is not visible.</p>
#
# <p>Also note that the default width of a text input field is 20 characters.</p>
#
# </body>
# </html>

# %%
soup = BeautifulSoup(text)

# %%
soup.title

# %%
soup.p
# Out:
# <p>Note that the form itself is not visible.</p>

# %%
soup.h2
# Out:
# <h2>Text Input</h2>

# %%
soup.form
# Out:
# <form>
#   First name:<br/>
# <input name="firstname" type="text"/>
# <br/>
#   Last name:<br/>
# <input name="lastname" type="text"/>
# </form>

# %%
soup.find_all("p")
# Out:
# [<p>Note that the form itself is not visible.</p>,
#  <p>Also note that the default width of a text input field is 20 characters.</p>]

# %%
soup.find_all("input")
# Out:
# [<input name="firstname" type="text"/>, <input name="lastname" type="text"/>]

# %%
soup.find_all("h2")
# Out:
# [<h2>Text Input</h2>]

# %%
print(text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Text Input</h2>
#
# <form>
#   First name:<br>
#   <input type="text" name="firstname">
#   <br>
#   Last name:<br>
#   <input type="text" name="lastname">
# </form>
#
# <p>Note that the form itself is not visible.</p>
#
# <p>Also note that the default width of a text input field is 20 characters.</p>
#
# </body>
# </html>

# %%
import requests

# %%
url = r"https://en.wikipedia.org/wiki/Shah_Rukh_Khan"

# %%
srk = open('srk.html','w')

# %%
text = requests.get(url)

# %%
srk.write(text.text)
# Out:
# 612923

# %%
url2 = r"https://www.google.com/"

# %%
response = requests.get(url2)

# %%
text = response.text

# %%
soup2 = BeautifulSoup(text)

# %%
soup2.find_all("a")
# Out:
# [<a class="gb1" href="https://www.google.co.in/imghp?hl=en&amp;tab=wi">Images</a>,
#  <a class="gb1" href="https://maps.google.co.in/maps?hl=en&amp;tab=wl">Maps</a>,
#  <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?gl=IN&amp;tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.co.in/nwshp?hl=en&amp;tab=wn">News</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a>,
#  <a class="gb1" href="https://www.google.co.in/intl/en/about/products?tab=wh" style="text-decoration:none"><u>More</u> »</a>,
#  <a class="gb4" href="http://www.google.co.in/history/optout?hl=en">Web History</a>,
#  <a class="gb4" href="/preferences?hl=en">Settings</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=en&amp;passive=true&amp;continue=https://www.google.com/" id="gb_70" target="_top">Sign in</a>,
# ...

# %%
soup2.find_all("img")
# Out:
# [<img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/>]

# %%
len(soup2.find_all("img"))
# Out:
# 1

# %%
soup2.find_all("a")
# Out:
# [<a class="gb1" href="https://www.google.co.in/imghp?hl=en&amp;tab=wi">Images</a>,
#  <a class="gb1" href="https://maps.google.co.in/maps?hl=en&amp;tab=wl">Maps</a>,
#  <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?gl=IN&amp;tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.co.in/nwshp?hl=en&amp;tab=wn">News</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a>,
#  <a class="gb1" href="https://www.google.co.in/intl/en/about/products?tab=wh" style="text-decoration:none"><u>More</u> »</a>,
#  <a class="gb4" href="http://www.google.co.in/history/optout?hl=en">Web History</a>,
#  <a class="gb4" href="/preferences?hl=en">Settings</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=en&amp;passive=true&amp;continue=https://www.google.com/" id="gb_70" target="_top">Sign in</a>,
# ...

# %%
url3 = r"https://www.goodreads.com/quotes"

# %%
response3 = requests.get(url3)

# %%
soup3 = BeautifulSoup(response3.text)

# %%
soup3.meta
# Out:
# <meta content="Popular quotes from Goodreads members. Marilyn Monroe: ‘I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times h..." name="description"/>

# %%
# soup3

# %%
soup3.find("div")
# Out:
# <div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}"><noscript data-react-checksum="-1362685725" data-reactid=".26q884xfpj4"></noscript></div>

# %%
soup3.find(class_='quotes').text
# Out:
# '\n\n\n\n\n\n\n      “I\'m selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can\'t handle me at my worst, then you sure as hell don\'t deserve me at my best.”\n    ―\n  \n    Marilyn Monroe\n  \n\n\n\n     tags:\n       attributed-no-source,\n       best,\n       life,\n       love,\n       mistakes,\n       out-of-control,\n       truth,\n       worst\n\n\n149829 likes\n\n\n\n\nLike\n\n\n\n\n\n\n\n\n\n      “Be yourself; everyone else is already taken.”\n    ―\n  \n    Oscar Wilde\n  \n\n\n\n     tags:\n       attributed-no-source,\n       be-yourself,\n       honesty,\n       inspirational,\n       misattributed-oscar-wilde\n\n\n148042 likes\n\n\n\n\nLike\n\n\n\n\n\n\n\n\n      “Two things are infinite: the universe and human stupidity; and I\'m not sure about the universe.”\n    ―\n  \n    Albert Einstein\n  \n\n\n\n     tags:\n       attributed-no-source,\n       human-nature,\n       humor,\n       infinity,\n
# ...

# %%
soup3.find_all("div")
# Out:
# [<div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}"><noscript data-react-checksum="-1362685725" data-reactid=".26q884xfpj4"></noscript></div>,
#  <div class="content">
#  <script>
#    //<![CDATA[
#      var initializeGrfb = function() {
#        $grfb.initialize({
#          appId: "2415071772",
#          grSession: false,
#          serverFBUser: null,
#          suppressAutoLogin: false
#        });
#      };
#      if (typeof $grfb !== "undefined") {
#        initializeGrfb();
#      } else {
#        window.addEventListener("DOMContentLoaded", function() {
#          if (typeof $grfb !== "undefined") {
#            initializeGrfb();
#          }
#        });
#      }
#    //]]>
#  </script>
#  <div class="siteHeader">
# ...

# %%
li = soup3.find_all("div",attrs={"class" : "quoteText"})

# %%
li
# Out:
# [<div class="quoteText">
#        “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Marilyn Monroe
#    </span>
#  </div>, <div class="quoteText">
#        “Be yourself; everyone else is already taken.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Oscar Wilde
#    </span>
#  </div>, <div class="quoteText">
#        “Two things are infinite: the universe and human stupidity; and I'm not sure about the universe.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Albert Einstein
#    </span>
#  </div>, <div class="quoteText">
#        “So many books, so little time.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Frank Zappa
#    </span>
#  </div>, <div class="quoteText">
# ...

# %%
item = li[0] #First quote

# %%
item
# Out:
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>

# %%
print(item.text)
# Out:
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#     ―
#
#     Marilyn Monroe

# %%
item.span.text
# Out:
# '\n    Marilyn Monroe\n  '

# %%
print(item)
# Out:
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>

# %%
item
# Out:
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>

# %%
item.text
# Out:
# "\n      “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”\n    ―\n  \n    Marilyn Monroe\n  \n"

# %%
item.text.strip().split("\n")
# Out:
# ["“I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”",
#  '    ―',
#  '  ',
#  '    Marilyn Monroe']

# %%
lines = item.text.strip().split("\n")

# %%
quote,author = lines[0],lines[-1].strip()

# %%
quote
# Out:
# "“I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”"

# %%
author
# Out:
# 'Marilyn Monroe'

# %%
li = soup3.find_all("div",attrs={"class" : "quoteText"})

# %%
# li

# %%
author_dict ={}

# %%
i=0
for author in li:
    author_dict[i] = soup3.find_all("div",attrs={"class" : "quoteText"})[i].span.text
    i += 1

# %%
author_dict
# Out:
# {0: '\n    Marilyn Monroe\n  ',
#  1: '\n    Oscar Wilde\n  ',
#  2: '\n    Albert Einstein\n  ',
#  3: '\n    Frank Zappa\n  ',
#  4: '\n    Bernard M. Baruch\n  ',
#  5: '\n    Marcus Tullius Cicero\n  ',
#  6: '\n    William W. Purkey\n  ',
#  7: '\n    Dr. Seuss\n  ',
#  8: '\n    Mae West\n  ',
#  9: '\n    Mahatma Gandhi\n  ',
#  10: '\n    Robert Frost\n  ',
#  11: '\n    J.K. Rowling,\n  ',
#  12: '\n    Albert Camus\n  ',
#  13: '\n    Eleanor Roosevelt,\n  ',
#  14: '\n    C.S. Lewis,\n  ',
#  15: '\n    Mark Twain\n  ',
#  16: '\n    Maya Angelou\n  ',
#  17: '\n    Elbert Hubbard\n  ',
#  18: '\n    Oscar Wilde\n  ',
#  19: '\n    Oscar Wilde\n  ',
#  20: '\n    Mahatma Gandhi\n  ',
#  21: '\n    Martin Luther King Jr.,\n  ',
#  22: '\n    Oscar Wilde,\n  ',
#  23: '\n    Friedrich Nietzsche,\n  ',
#  24: '\n    Stephen Chbosky,\n  ',
#  25: '\n    Ralph Waldo Emerson\n  ',
#  26: '\n    Rob Siltanen\n  ',
#  27: '\n    Narcotics Anonymous\n  ',
# ...

# %%
type(len(li))
# Out:
# int

# %%
quotes = soup3.find_all("div",attrs={"class" : "quote"})

# %%
quotes
# Out:
# [<div class="quote">
#  <div class="quoteDetails">
#  <a class="leftAlignedImage" href="https://images.gr-assets.com/quotes/1511992603p8/8630.jpg">
#  <img alt="I'm selfish, impatient and a little insecure. I make mistakes, I am out of control" src="https://images.gr-assets.com/quotes/1511992603p2/8630.jpg"/>
#  </a>
#  <div class="quoteText">
#        “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Marilyn Monroe
#    </span>
#  </div>
#  <div class="quoteFooter">
#  <div class="greyText smallText left">
#       tags:
#         <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#         <a href="/quotes/tag/best">best</a>,
#         <a href="/quotes/tag/life">life</a>,
#         <a href="/quotes/tag/love">love</a>,
# ...

# %%
quote_items = quotes[0]

# %%
item = quote_items.find_next("div",attrs={"class" : "quoteText"})

# %%
item
# Out:
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>

# %%
left = quote_items.find_next("div",attrs={"class" : "left"})

# %%
left
# Out:
# <div class="greyText smallText left">
#      tags:
#        <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#        <a href="/quotes/tag/best">best</a>,
#        <a href="/quotes/tag/life">life</a>,
#        <a href="/quotes/tag/love">love</a>,
#        <a href="/quotes/tag/mistakes">mistakes</a>,
#        <a href="/quotes/tag/out-of-control">out-of-control</a>,
#        <a href="/quotes/tag/truth">truth</a>,
#        <a href="/quotes/tag/worst">worst</a>
# </div>

# %%
li_tag_links = left.find_all("a")

# %%
li_tags = [tag_links.text for tag_links in li_tag_links]

# %%
li_tags
# Out:
# ['attributed-no-source',
#  'best',
#  'life',
#  'love',
#  'mistakes',
#  'out-of-control',
#  'truth',
#  'worst']

# %%
total =[]

# %%
total = []
for quote_items in quotes:
    item =quote_items.find_next("div",attrs={"class" : "quoteText"}) 
    lines = item.text.strip().split("\n")
    
    left = quote_items.find_next("div",attrs={"class" : "left"})
    
    li_tag_links = left.find_all("a")
    li_tags = [tag_links.text for tag_links in li_tag_links]
    
    dict_quote = {
        "quote" : quote,
        "author" : author,
        "tags" : li_tags
    }
    total.append(dict_quote)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-211-0099dde42430> in <module>
#      12         "quote" : quote,
#      13         "author" : author,
# ---> 14         "tags" : tags
#      15     }
#      16     total.append(dict_quote)
#
# NameError: name 'tags' is not defined
